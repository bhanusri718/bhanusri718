# %%
import pandas as pd

# %%
movies =pd.read_csv(r'C:\Users\YESHWANTH\Downloads\Movie-Rating.csv')

# %%
movies.shape
# Out:
# (559, 6)

# %%
movies.size
# Out:
# 3354

# %%
movies.info
# Out:
# <bound method DataFrame.info of                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# ...

# %%
movies.isnull()
# Out:
#       Film  Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 0    False  False                      False               False
# 1    False  False                      False               False
# 2    False  False                      False               False
# 3    False  False                      False               False
# 4    False  False                      False               False
# ..     ...    ...                        ...                 ...
# 554  False  False                      False               False
# 555  False  False                      False               False
# 556  False  False                      False               False
# 557  False  False                      False               False
# 558  False  False                      False               False
#
#      Budget (million $)  Year of release
# 0                 False            False
# 1                 False            False
# 2                 False            False
# ...

# %%
movies.isnull().sum()
# Out:
# Film                         0
# Genre                        0
# Rotten Tomatoes Ratings %    0
# Audience Ratings %           0
# Budget (million $)           0
# Year of release              0
# dtype: int64

# %%
movies.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film', 'Genre', 'CriticRating','AudienceRatings',
       'BudgetMillion', 'Year']

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'CriticRating', 'AudienceRatings', 'BudgetMillion',
#        'Year'],
#       dtype='object')

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRatings  BudgetMillion         Year
# count    559.000000       559.000000     559.000000   559.000000
# mean      47.309481        58.744186      50.236136  2009.152057
# std       26.413091        16.826887      48.731817     1.362632
# min        0.000000         0.000000       0.000000  2007.000000
# 25%       25.000000        47.000000      20.000000  2008.000000
# 50%       46.000000        58.000000      35.000000  2009.000000
# 75%       70.000000        72.000000      65.000000  2010.000000
# max       97.000000        96.000000     300.000000  2011.000000

# %%
movies.Film =movies.Film .astype('category')

# %%
movies.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: category
# Categories (559, object): ['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours', ..., 'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper']

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Genre            559 non-null    object
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillion    559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
movies.Genre =movies.Genre .astype('category')
movies.Year =movies.Year.astype('category')

# %%
movies.CriticRating =movies.CriticRating.astype('int')

# %%
movies.CriticRating
# Out:
# 0      87
# 1       9
# 2      30
# 3      93
# 4      55
#        ..
# 554    26
# 555    68
# 556    89
# 557    90
# 558    14
# Name: CriticRating, Length: 559, dtype: int32

# %%
movies.AudienceRatings =movies.AudienceRatings.astype('int')

# %%
movies.CriticRating
# Out:
# 0      87
# 1       9
# 2      30
# 3      93
# 4      55
#        ..
# 554    26
# 555    68
# 556    89
# 557    90
# 558    14
# Name: CriticRating, Length: 559, dtype: int32

# %%
movies.Genre
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Genre, Length: 559, dtype: category
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
movies.Year
# Out:
# 0      2009
# 1      2008
# 2      2009
# 3      2010
# 4      2009
#        ...
# 554    2011
# 555    2009
# 556    2007
# 557    2009
# 558    2011
# Name: Year, Length: 559, dtype: category
# Categories (5, int64): [2007, 2008, 2009, 2010, 2011]

# %%
movies.Year.cat.categories
# Out:
# Index([2007, 2008, 2009, 2010, 2011], dtype='int64')

# %%
# How to working with joint plots

from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
j = sns.jointplot( data = movies, x = 'CriticRating', y = 'AudienceRatings')
plt.show()
# Audience rating is more dominant then critics rating
# Based on this we find out as most people are most liklihood to watch audience rating & less likely to wathc critics rating
# let me explain the excel - if you filter audience rating & critic rating. critic rating has very low values compare to audience rating

# %%
j = sns.jointplot( data = movies, x = 'CriticRating', y = 'AudienceRatings', kind='kde')
plt.show()

# %%
j = sns.jointplot( data = movies, x = 'CriticRating', y = 'AudienceRatings', kind='resid')
plt.show()

# %%
##Histograms

# <<< chat1

m1 = sns.distplot(movies.AudienceRatings)
plt.show()
#y - axis generated by seaborn automatically that is the powefull of seaborn gallery

# %%
sns.set_style('darkgrid')
plt.show()

# %%
m2 = sns.distplot(movies.AudienceRatings, bins = 15)
plt.show()

# %%
sns.set_style('darkgrid')

# %%
n1 = sns.distplot(movies.AudienceRatings, bins = 15)
plt.show()

# %%
sns.set_style('white') #normal distribution & called as bell curve
n1 = sns.distplot(movies.AudienceRatings, bins = 15)
plt.show()

# %%
n1 = sns.distplot(movies.CriticRating, bins = 25)
plt.show()

# %%
#h1 = plt.hist(movies.BudgetMillions)

plt.hist(movies.BudgetMillion)
plt.show()

# %%
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillion)
plt.show()

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRatings  \
# 0  (500) Days of Summer      Comedy            87               81
# 1            10,000 B.C.  Adventure             9               44
# 2             12 Rounds      Action            30               52
# 3              127 Hours  Adventure            93               84
# 4              17 Again      Comedy            55               70
#
#    BudgetMillion  Year
# 0              8  2009
# 1            105  2008
# 2             20  2009
# 3             18  2010
# 4             20  2009

# %%
movies.Genre.unique()
# Out:
# ['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance', 'Thriller']
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
plt.hist(movies[movies.Genre == 'Action'].BudgetMillion, bins = 20)
plt.hist(movies[movies.Genre == 'Thriller'].BudgetMillion, bins = 20)
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillion, bins = 20)
plt.legend()
plt.show()

# %%
plt.hist([movies[movies.Genre == 'Action'].BudgetMillion, \
         movies[movies.Genre == 'Thriller'].BudgetMillion,\
         movies[movies.Genre == 'Drama'].BudgetMillion], 
         bins = 20 ,stacked = True)
plt.show()

# %%
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
vis1 = sns.lmplot(data=movies, x='CriticRating', y='AudienceRatings',\
                 fit_reg=False)
plt.show()

# %%
vis1 = sns.lmplot(data=movies, x='CriticRating', y='AudienceRatings',\
                 fit_reg=False,hue='Genre')
plt.show()

# %%
plt.style.use('dark_background')
vis1 = sns.lmplot(data=movies, x='CriticRating', y='AudienceRatings',\
                 fit_reg=False,hue ='Genre',aspect=1)
plt.show()

# %%
plt.style.use('dark_background')

# %%
k1 = sns.kdeplot(x ='CriticRating',y ='AudienceRatings', data = movies )
plt.show()
# where do u find more density and how density is distibuted across from the the chat 
# center point is kernal this is calld KDE & insteade of dots it visualize like this
# we can able to clearly see the spread at the audience ratings

# %%
k1 = sns.kdeplot(data=movies, x='CriticRating', y='AudienceRatings', shade=True, shade_lowest=False, cmap='Reds')
plt.show()

# %%
k2 =sns.kdeplot(data=movies, x='CriticRating', y='AudienceRatings', shade=True, shade_lowest=False, cmap='Pastel1')
plt.show()

# %%
sns.set_style('white')
k1=sns.kdeplot(data=movies, x='CriticRating', y='AudienceRatings', shade=True, shade_lowest=False, cmap='nipy_spectral')
plt.show()

# %%
k1 = sns.kdeplot(data = movies, x = 'BudgetMillion',y ='AudienceRatings',shade_lowest=False,cmap='Oranges')
plt.show()

# %%
k1 = sns.kdeplot(data = movies, x = 'BudgetMillion',y ='AudienceRatings')
plt.show()

# %%
#subplots

f, ax = plt.subplots(1,2, figsize =(12,6))
plt.show()

# %%
#subplots

f, ax = plt.subplots(3,3, figsize =(12,6))
plt.show()

# %%
f, axes = plt.subplots(1,2, figsize =(12,6))

k1 = sns.kdeplot(data = movies,x ='BudgetMillion',y = 'AudienceRatings',ax=axes[0])
k2 = sns.kdeplot(data = movies,x ='BudgetMillion',y = 'CriticRating',ax = axes[1])
plt.show()

# %%
axes
# Out:
# array([<Axes: xlabel='BudgetMillion', ylabel='AudienceRatings'>,
#        <Axes: xlabel='BudgetMillion', ylabel='CriticRating'>],
#       dtype=object)

# %%
#Box plots - 

w = sns.boxplot(data=movies, x='Genre', y = 'CriticRating')
plt.show()

# %%
#violin plot
z = sns.violinplot(data=movies, x='Genre', y = 'CriticRating')
plt.show()

# %%
w1 = sns.boxplot(data=movies[movies.Genre == 'Drama'], x='Year', y = 'CriticRating')
plt.show()

# %%
z = sns.violinplot(data=movies[movies.Genre == 'Drama'], x='Year', y = 'CriticRating')
plt.show()

# %%
# Createing a Facet grid
plt.style.use('default')

# %%
g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre') #kind of subplots
plt.show()

# %%
plt.style.use('dark_background')
plt.scatter(movies.CriticRating,movies.AudienceRatings)
plt.show()

# %%
plt.style.use('dark_background')
g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRatings' ) 
plt.show()

# %%
# you can populated any type of chat. 

g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.hist, 'BudgetMillion') #scatterplots are mapped in facetgrid
plt.show()

# %%
g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
kws = dict(s=50, linewidth=0.5,edgecolor='black')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRatings',**kws )
plt.show()
#scatterplots are mapped in facetgrid

# %%
# python is not vectorize programming language
# Building dashboards (dashboard - combination of chats)

sns.set_style('ticks')
f, axes = plt.subplots (2,2, figsize = (8,8))

k1 = sns.kdeplot(x = movies.BudgetMillion,y = movies.AudienceRatings,ax=axes[0,0])
k2 = sns.kdeplot(x = movies.BudgetMillion,y = movies.CriticRating,ax = axes[0,1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

z = sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', y = 'CriticRating', ax=axes[1,0])

k4 = sns.kdeplot(x = movies.CriticRating,y=movies.AudienceRatings,shade = True,shade_lowest=False,cmap='Reds',ax=axes[1,1])

k4b = sns.kdeplot(x = movies.CriticRating,y = movies.AudienceRatings,cmap='Reds',ax = axes[1,1])

plt.show()

# %%
# How can you style your dashboard  using different color map

# python is not vectorize programming language
# Building dashboards (dashboard - combination of chats)

sns.set_style('dark',{'axes.facecolor':'black'})
f, axes = plt.subplots (2,2, figsize = (15,15))
#plot [0,0]
k1 = sns.kdeplot(x = movies.BudgetMillion,y = movies.AudienceRatings, \
                 shade = True, shade_lowest=True,cmap = 'inferno', \
                 ax = axes[0,0])
k1b = sns.kdeplot(x= movies.BudgetMillion,y =  movies.AudienceRatings, \
                 cmap = 'cool',ax = axes[0,0])

#plot [0,1]
k2 = sns.kdeplot(x= movies.BudgetMillion,y=movies.CriticRating,\
                 shade=True, shade_lowest=True, cmap='inferno',\
                 ax = axes[0,1])
k2b = sns.kdeplot(x=movies.BudgetMillion,y=movies.CriticRating,\
                  cmap = 'cool', ax = axes[0,1])

#plot[1,0]
z = sns.violinplot(data=movies[movies.Genre=='Drama'], \
                   x='Year', y = 'CriticRating', ax=axes[1,0])

#plot[1,1]
k4 = sns.kdeplot(x = movies.CriticRating,y =movies.AudienceRatings, \
                 shade = True,shade_lowest=False,cmap='Blues_r', \
                 ax=axes[1,1])

k4b = sns.kdeplot(x = movies.CriticRating,y = movies.AudienceRatings, \
                  cmap='gist_gray_r',ax = axes[1,1])


k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

plt.show()

# %%
##Final discussion what we learn so far - 
1> category datatype in python
2> jointplots
3> histogram
4> stacked histograms
5> Kde plot
6> subplot
7> violin plots
8> Factet grid
9> Building dashboards

# %%
## eda is completed
