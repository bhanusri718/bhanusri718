# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st
# %matplotlib inline

# %%
df = pd.read_excel(r'C:\Users\YESHWANTH\Downloads\cars graph.xlsx')

# %%
df
# Out:
#   name of the car  frequency  year
# 0        mercedes        170   2024
# 1           volvo        598   2024
# 2         porsche        114   2024
# 3            audi        700   2024

# %%
df.columns
# Out:
# Index(['name of the car', 'frequency', 'year '], dtype='object')

# %%
df.isnull()
# Out:
#    name of the car  frequency  year
# 0            False      False  False
# 1            False      False  False
# 2            False      False  False
# 3            False      False  False

# %%
df.category=['name of the car', 'frequency', 'year ']
df.category
# Out:
# C:\Users\YESHWANTH\AppData\Local\Temp\ipykernel_15692\1956931392.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.category=['name of the car', 'frequency', 'year ']
# ['name of the car', 'frequency', 'year ']

# %%
df.info
# Out:
# <bound method DataFrame.info of   name of the car  frequency  year
# 0        mercedes        170   2024
# 1           volvo        598   2024
# 2         porsche        114   2024
# 3            audi        700   2024>

# %%
df.describe()
# Out:
#        frequency   year
# count    4.00000     4.0
# mean   395.50000  2024.0
# std    296.54623     0.0
# min    114.00000  2024.0
# 25%    156.00000  2024.0
# 50%    384.00000  2024.0
# 75%    623.50000  2024.0
# max    700.00000  2024.0

# %%
sns.set(style="whitegrid")

# %%
vis1 = sns.displot(df['name of the car'])
sns.set(style="whitegrid")
plt.show()

# %%
df [x ="name of the car", y="frequency"].value_counts().plot(kind="bar")
plt.show()
# Out:
#   Cell In[69], line 1
#     df [x ="name of the car", y="frequency"].value_counts().plot(kind="bar")
#         ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
f, ax = plt.subplots(figsize=(10, 6))
ax = sns.countplot(x="name of the car", hue="frequency", data=df)
plt.show()

# %%
f, ax = plt.subplots(figsize=(8, 6))
sns.stripplot(x="name of the car", y="frequency", data=df)
plt.show()

# %%
df["name of the car"].value_counts().plot(kind="pie")
plt.show()

# %%
plt.plot(kind='pie',figsize=(10,10))
plt.show()
