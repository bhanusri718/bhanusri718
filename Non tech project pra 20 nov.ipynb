# %%
import openpyxl

workbook = openpyxl.Workbook()
sheet = workbook.active
 
data = [ 
    ['NAME','DOMAIN','AGE','LOCATION','SALARY','EXP'],
    ['BUNNY','TEST',22,'HYD',22000,2],
    ['KL','PYTH',55,'sdp',5555,5],
    ['sunny','c',26,'wgl',8000,1]
]
 
for row in data:
   sheet.append(row)
    
workbook.save('data.xlsx')

# %%
data
# Out:
# [['NAME', 'DOMAIN', 'AGE', 'LOCATION', 'SALARY', 'EXP'],
#  ['BUNNY', 'TEST', 22, 'HYD', 22000, 2],
#  ['KL', 'PYTH', 55, 'sdp', 5555, 5],
#  ['sunny', 'c', 26, 'wgl', 8000, 1]]

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\YESHWANTH'

# %%
emp = pd.read_excel(r'C:\\Users\\YESHWANTH\data.xlsx')
emp
# Out:
#     NAME DOMAIN  AGE LOCATION  SALARY  EXP
# 0  BUNNY   TEST   22      HYD   22000    2
# 1     KL   PYTH   55      sdp    5555    5
# 2  sunny      c   26      wgl    8000    1

# %%
emp.shape
# Out:
# (3, 6)

# %%
emp.columns
# Out:
# Index(['NAME', 'DOMAIN', 'AGE', 'LOCATION', 'SALARY', 'EXP'], dtype='object')

# %%
len(emp.columns)
# Out:
# 6

# %%
len(emp)
# Out:
# 3

# %%
emp
# Out:
#     NAME DOMAIN  AGE LOCATION  SALARY  EXP
# 0  BUNNY   TEST   22      HYD   22000    2
# 1     KL   PYTH   55      sdp    5555    5
# 2  sunny      c   26      wgl    8000    1

# %%
emp['SALARY']
# Out:
# 0    22000
# 1     5555
# 2     8000
# Name: SALARY, dtype: int64

# %%
emp[['SALARY','EXP']]
# Out:
#    SALARY  EXP
# 0   22000    2
# 1    5555    5
# 2    8000    1

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
vis1 = sns.displot(emp['SALARY'])

# %%
vis2 = sns.distplot(emp['SALARY'])
# Out:
# C:\Users\YESHWANTH\AppData\Local\Temp\ipykernel_7740\51933769.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   vis2 = sns.distplot(emp['SALARY'])

# %%
vis3 = plt.hist(emp['SALARY'])

# %%
emp
# Out:
#     NAME DOMAIN  AGE LOCATION  SALARY  EXP
# 0  BUNNY   TEST   22      HYD   22000    2
# 1     KL   PYTH   55      sdp    5555    5
# 2  sunny      c   26      wgl    8000    1

# %%
 plt.rcParams['figure.figsize'] =1,1

# %%
vis5 = sns.lmplot(data=emp, x ='EXP' , y = 'SALARY',fit_reg = False)

# %%
vis5 = sns.lmplot(data=emp, x ='EXP' , y = 'SALARY',fit_reg = True)

# %%
vis5 = sns.lmplot(data=emp, x = 'EXP',y = 'SALARY')
